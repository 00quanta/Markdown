# %%
from sympy import *

# %%
init_printing()

# %%
Integral(sqrt(1/x), x)
# Out:
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡

# %%
simplify(sin(x)**2 + cos(x)**2)
# Out:
# 1

# %%
x = np.arange(0, 3*np.pi, 0.2)
y = np.sin(x)
a = plt.subplot()
a.plot(x, y)
a.grid()
plt.show()

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quandratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')
plt.title('simple plot')
plt.legend()
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 200, endpoint=True)
c, s = np.cos(x), np.sin(x)

plt.figure(figsize=(8, 6), dpi=80)
plt.plot(x, c)
plt.plot(x, s)
plt.grid()
plt.show()

# %%
colors = [3, -200, 'hello']

# %%
[i**2 for i in range(4)]
# Out:
# [0, 1, 4, 9]

# %%
a = 10000
nums = [(4*i**2)/(4*i**2-1) for i in range(a)]

# %%
b = 1
pi = 1
while b < a:
    pi *= nums[b]
    b += 1
pi = pi*2

# %%
pi
# Out:
# 3.1415141108281714

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-np.pi, np.pi, 2000)
y = np.cos(x) + 0.3*np.random.rand(2000)
p = np.polynomial.Chebyshev.fit(x, y, 90)

t = np.linspace(-1, 1, 200)
plt.gca()
plt.plot(x, y, '.')
plt.plot(t, p(t), 'r-', lw=3)
plt.savefig("exercise_2.png", figsize=(10, 10), dpi=200)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$\pi/2$', r'$\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0xa174358>,
#   <matplotlib.axis.XTick at 0xa1747f0>,
#   <matplotlib.axis.XTick at 0xa190860>,
#   <matplotlib.axis.XTick at 0xa190a90>,
#   <matplotlib.axis.XTick at 0xa198240>],
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# #### Finding the minimum of a smooth function

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**2 + 10*np.sin(x)

# %%
a = np.arange(-10, 10, 0.1)
plt.plot(a, f(a))
plt.show()

# %%
import scipy
from scipy import optimize
result = optimize.minimize(f, x0=0)
result
# Out:
#       fun: -7.945823375615215
#  hess_inv: array([[0.08589237]])
#       jac: array([-1.1920929e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 18
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([-1.30644012])

# %%
import scipy.integrate

# %%
from scipy.integrate import quad

# %%
res, err = quad(np.sin, 0, np.pi/2)

# %%
import numpy
from numpy import poly1d

# %%
p = poly1d([3,4,5])

# %%
print(p)
# Out:
#    2
# 3 x + 4 x + 5

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\xie.maozhou'

# %%
# %%latex
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}
# Out:
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
#
#
# \end{equation}

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# Some of the **greatest**
# discoveries in *science*
# were made by accident.

# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
\nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
\nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
\nabla \cdot \vec{\mathbf{B}} & = 0 
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{eqnarray}

# %%
# %%latex
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{eqnarray}
# Out:
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{eqnarray}

# %% [markdown]
# The mass-energy equivalence is described by the famous equation
#
# $$E=mc^2$$
#
# discovered in 1905 by Albert Einstein.
# In natural units ($c$ = 1), the formula expresses the identity
#
# \begin{equation}
# E=m
# \end{equation}

# %% [markdown]
# $\int_a^b x^2 dx$

# %% [markdown]
# $\iint_\limits{V} \mu(u,v) \,du\,dv$
